# %%
import urllib.request
from bs4 import BeautifulSoup
from html.parser import HTMLParser
import re

# %%
#crab news

path='https://www.rle.mit.edu/boib/news/'
htmlfile=urllib.request.urlopen(path)
Soup = BeautifulSoup(htmlfile, "html.parser")
print(Soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <title>News  |  Biomedical Optical Imaging and Biophotonics Group</title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.rle.mit.edu/boib/wp-content/themes/boib_theme/style.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://www.rle.mit.edu/boib/xmlrpc.php" rel="pingback"/>
# <script src="https://www.rle.mit.edu/boib/wp-content/themes/boib_theme/scripts/jquery-2.0.2.min.js"></script>
# <script src="https://www.rle.mit.edu/boib/wp-content/themes/boib_theme/scripts/scripts.js" type="text/javascript"></script>
# <script src="//use.typekit.net/rir7mwj.js" type="text/javascript"></script>
# <script type="text/javascript">try{Typekit.load();}catch(e){}</script>
# <link href="//s.w.org" rel="dns-prefetch"/>
# ...

# %%
path='https://www.rle.mit.edu/boib/news/'
htmlfile=urllib.request.urlopen(path)
Soup = BeautifulSoup(htmlfile, "html.parser")
print(Soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <title>News  |  Biomedical Optical Imaging and Biophotonics Group</title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.rle.mit.edu/boib/wp-content/themes/boib_theme/style.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://www.rle.mit.edu/boib/xmlrpc.php" rel="pingback"/>
# <script src="https://www.rle.mit.edu/boib/wp-content/themes/boib_theme/scripts/jquery-2.0.2.min.js"></script>
# <script src="https://www.rle.mit.edu/boib/wp-content/themes/boib_theme/scripts/scripts.js" type="text/javascript"></script>
# <script src="//use.typekit.net/rir7mwj.js" type="text/javascript"></script>
# <script type="text/javascript">try{Typekit.load();}catch(e){}</script>
# <link href="//s.w.org" rel="dns-prefetch"/>
# ...

# %%
news=Soup.select('body>div#mainsite > div#interiorcontent > div#interiorleft > p ')
links=Soup.select('body>div#mainsite > div#interiorcontent > div#interiorleft > p > a')
images=Soup.select('body>div#mainsite > div#interiorcontent > div#interiorleft > p > img')
videos=Soup.select('body>div#mainsite > div#interiorcontent > div#interiorleft > p > iframe')
print(images)
print(videos)

i = 0
data = []
for new in news:
    time=re.findall(r'<p style="margin-bottom:0px;">(\d+.\d+.\d+)<br/>', str(new), re.S)
#    print(str(new))
    img=images[i].get('src')
    video = videos[i].get('src')
    if time == []:
        continue
    else:
        if img == None:
            img = ''
        if video == None:
            video=''
        
        info={
        'time' : time,
        'title' : links[i].get_text(),
        'tlink' : links[i].get('href'),
        'plink' : img,
        'vlink' : video
        }
        i = i + 1
        data.append(info)
print(data)

#for link in links:
 #   print(link.get('href'))
  #  print(link.get_text())
# Out:
# [<img alt="" class="attachment-thumbnail size-thumbnail wp-post-image" height="118" sizes="(max-width: 150px) 100vw, 150px" src="https://www.rle.mit.edu/boib/wp-content/uploads/2014/06/image903-150x118.png" srcset="https://www.rle.mit.edu/boib/wp-content/uploads/2014/06/image903-150x118.png 150w, https://www.rle.mit.edu/boib/wp-content/uploads/2014/06/image903.png 179w" width="150"/>, <img alt="" class="attachment-thumbnail size-thumbnail wp-post-image" height="25" sizes="(max-width: 150px) 100vw, 150px" src="https://www.rle.mit.edu/boib/wp-content/uploads/2014/06/image4961-150x25.png" srcset="https://www.rle.mit.edu/boib/wp-content/uploads/2014/06/image4961-150x25.png 150w, https://www.rle.mit.edu/boib/wp-content/uploads/2014/06/image4961.png 180w" width="150"/>, <img alt="" class="attachment-thumbnail size-thumbnail wp-post-image" height="89" sizes="(max-width: 150px) 100vw, 150px" src="https://www.rle.mit.edu/boib/wp-content/uploads/2014/06/image799-150x89.jpg" srcset="https://www
# ...

# %%
import json

# %%
file = open('Desktop/news.json','w')
json.dump(data,file,ensure_ascii=False)
file.close()

# %%
#crab people
peoplepath='https://www.rle.mit.edu/boib/people/'
htmlfile=urllib.request.urlopen(peoplepath)
Soup = BeautifulSoup(htmlfile, "html.parser")
print(Soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <title>People  |  Biomedical Optical Imaging and Biophotonics Group</title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.rle.mit.edu/boib/wp-content/themes/boib_theme/style.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://www.rle.mit.edu/boib/xmlrpc.php" rel="pingback"/>
# <script src="https://www.rle.mit.edu/boib/wp-content/themes/boib_theme/scripts/jquery-2.0.2.min.js"></script>
# <script src="https://www.rle.mit.edu/boib/wp-content/themes/boib_theme/scripts/scripts.js" type="text/javascript"></script>
# <script src="//use.typekit.net/rir7mwj.js" type="text/javascript"></script>
# <script type="text/javascript">try{Typekit.load();}catch(e){}</script>
# <link href="//s.w.org" rel="dns-prefetch"/>
# ...

# %%
# member=Soup.select('body>div#mainsite > div#interiorcontent > div#interiorleft > table#tablepress-1 > tbody >tr')
# item=Soup.select('body>div#mainsite > div#interiorcontent > div#interiorleft >  table#tablepress-1 > tbody > tr > td.column-1')

# title=Soup.select('body>div#mainsite > div#interiorcontent > div#interiorleft >  table#tablepress-1 > tbody > tr > td.column-2')
# phone=Soup.select('body>div#mainsite > div#interiorcontent > div#interiorleft >  table#tablepress-1 > tbody > tr > td.column-3')
# room=Soup.select('body>div#mainsite > div#interiorcontent > div#interiorleft >  table#tablepress-1 > tbody > tr > td.column-4')

items = Soup.find_all('tr')
for tr in items:
    

# a=0
# for i in member:
#     print(i.get_text())
# Out:
# Cahill, Lucas C.Research Assistant
# 617.253.852036-337
#
#
#
# Chen, SiyuPostdoctoral Associate617.253.548136-355
#
#
# Fleischer, Dorothy A.Administrative Assistant617.253.157036-345
#
#
# Fujimoto, James G.Professor of Electrical Engineering617.253.852836-361
#
#
# Lin, JunhongResearch Assistant
# 617.253.893936-369
#
#
# Moult, Eric M.Graduate Student Research Assistant617.253.852036-369
#
#
# Potsaid, Benjamin M.Visiting Scientist617.253.893936-357
#
#
# Yoshitake, TadayukiResearch Fellow617.253.890836-347
#
#
# Yu, YueVisiting Student617.253.893936-369
#
#
# Zhang, JasonResearch Assistant617.253.852036-337

# %%
i=0
data = []
for new in news:
    time=re.findall(r'<p style="margin-bottom:0px;">(\d+.\d+.\d+)<br/>', str(new), re.S)
#    print(str(new))
    img=images[i].get('src')
    video = videos[i].get('src')
    if time == []:
        continue
    else:
        if img == None:
            img = ''
        if video == None:
            video=''
        
        info={
        'time' : time,
        'title' : links[i].get_text(),
        'tlink' : links[i].get('href'),
        'plink' : img,
        'vlink' : video
        }
        i = i + 1
        data.append(info)
print(data)
